# %%
import chromadb

# %%
client=chromadb.Client()
collection=client.create_collection(name="my_collection",)

# %%
collection.add(documents=['this is for pineapple',
                          'this is for orange'],
                          ids=['id1','id2'])
# Out:
# C:\Users\Pakistan\.cache\chroma\onnx_models\all-MiniLM-L6-v2\onnx.tar.gz:   6%|▌         | 4.58M/79.3M [01:17<21:08, 61.8kiB/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 collection.add(documents=['this is for pineapple',
#       2                           'this is for orange'],
#       3                           ids=['id1','id2'])
#
# File c:\ProgramData\anaconda3\Lib\site-packages\chromadb\api\models\Collection.py:80, in Collection.add(self, ids, embeddings, metadatas, documents, images, uris)
#      40 def add(
#      41     self,
#      42     ids: OneOrMany[ID],
#    (...)
#      52     uris: Optional[OneOrMany[URI]] = None,
#      53 ) -> None:
#      54     """Add embeddings to the data store.
#      55     Args:
#      56         ids: The ids of the embeddings you wish to add
#    (...)
#      72
#      73     """
#      74     (
# ...
